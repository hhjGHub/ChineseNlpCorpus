# %% [markdown]
# # gazx 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/gazx/gazx.csv)
# 1. **数据概览：** 0.67 福建公安公众服务咨询回复数据
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 福建公安公众服务--咨询回复
# 4. **加工处理：**
#     1. 过滤了id、url字段
#     2. 对title、content、reply_c做了脱敏处理

# %%
import pandas as pd

# %%
path = 'govzx_文件夹_所在_路径'

# %% [markdown]
# # 1.gazx.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'gazx.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | release_t | 发布时间 |
# | title | 诉讼标题 |
# | transfer_u | 转办单位 |
# | content | 诉讼内容 |
# | expect_t | 预计回复时间 |
# | reply_c | 回复意见 |
# | satisfy_d | 满意度 |
# | evaluate_t | 评论时间 |
# | evaluate_c | 评论内容 |

# %%
pd_all.sample(n=20)
# Out:
#        release_t                 title  \
# 5051   2014/8/11             关于移民美国的问题
# 3617   2013/7/24          大中专毕业开户口迁出证明
# 4289   2014/2/27    港澳通行证过期后几天才能办理续签呢？
# 684    2010/9/29                  户口迁移
# 155   2009/12/30  网上缴纳交通违法罚款填错一个号怎么挽救？
# 3103    2013/4/2       网上申请港澳通行证网上再次签注
# 477    2010/7/19             身份证真伪查询工具
# 5250  2014/10/15             我女儿户口落户问题
# 1880  2011/12/14              外地驾照转回本地
# 3707    2013/7/3             套牌闽CMU815
# 256     2010/3/2   在外务工人员如何办理《无犯罪记录证明》
# 1323   2011/6/27         加急二代身份证办理情况咨询
# 3870    2013/8/8                车辆违章处理
# 5027   2014/8/21             办理户口的几点疑问
# 5309   2015/1/14           关于子女落户的问题咨询
# 1801   2012/1/10    香港人没有中国身份证如何网上自主选号
# 6385   2015/12/1            有关超标电动车的处理
# 2704  2012/10/19                    户籍
# 3505   2013/5/30      右转弯也打转向灯也得停红绿灯吗？
# 3450   2013/6/13             违章是否及时通知？
#
#                                                 content transfer_u  \
# ...
