# %% [markdown]
# # govline 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/govline/govline.csv)
# 1. **数据概览：** 0.69 万条行政服务网上咨询数据
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 厦门市行政服务中心
# 4. **加工处理：**
#     1. 过滤了id、url字段
#     2. 对title、content做了脱敏处理

# %%
import pandas as pd

# %%
path = 'govline_文件夹_所在_路径'

# %% [markdown]
# # 1.govline.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'govline.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | title | 诉讼标题 |
# | time | 提交时间 |
# | content | 诉讼内容 |
# | repcontent| 处理情况 |
# | reply_p| 回复人 |
# | reply_t | 回复时间 |

# %%
pd_all.sample(n=20)
# Out:
#                      title             time  \
# 3715            分公司变更营业饭范围    2015/9/7 0:00
# 201              限购令下还能买房吗    2012/7/9 0:00
# 2507            户口迁入厦门所需材料    2015/3/7 0:00
# 4736        办理暂住信息查询需要带什么？   2014/5/12 0:00
# 6379              房产证加子女名字    2017/3/2 0:00
# 2263                 办理排水证    2014/9/5 0:00
# 3502            如何变更公司经营地址    2016/4/7 0:00
# 1470                户口转移问题  2013/10/28 0:00
# 106    如何办理一次（或二次）访问签证通知函？    2012/5/8 0:00
# 2915   请帮忙排一下消防竣工验收材料装订的顺序   2016/8/19 0:00
# 5506      国有土地使用权有偿出让契税通知书   2012/12/6 0:00
# 5716  哪些防雷装置应当经过设计审核和竣工验收？    2012/5/8 0:00
# 5119               入住情况调查表   2013/6/28 0:00
# 1278              关于营业执照注销   2013/8/19 0:00
# 501                  房屋登记费  2012/10/15 0:00
# 1674          暂住证缓办怎么办--急等   2014/1/23 0:00
# 1822    是否接受非厦门本地专科生就业协议档案   2014/4/23 0:00
# 4041                  户口调动    2015/6/1 0:00
# 1457            外地人员户口迁入问题  2013/10/30 0:00
# 1334            申领一次性失业补助金  2013/12/20 0:00
#
# ...
