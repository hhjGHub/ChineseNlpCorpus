# %% [markdown]
# # govhac 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/govhac/govhac.csv)
# 1. **数据概览：** 0.8 万条厦门市海沧区人民政府市民互动交流数据
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 厦门市海沧区人民政府
# 4. **加工处理：**
#     1. 过滤了id、url字段
#     2. 对title、content做了脱敏处理

# %%
import pandas as pd

# %%
path = 'govhac_文件夹_所在_路径'

# %% [markdown]
# # 1.govhac.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'govhac.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | letter_type | 内容类型 |
# | title | 标题 |
# | post_t | 发表日期 |
# | letter_style| 信件类型 |
# | content_ask| 咨询内容 |
# | reply_dep | 答复部门 |
# | reply_t | 发布时间 |
# | reply_c | 答复内容 |

# %%
pd_all.sample(n=20)
# Out:
#      letter_type                             title      post_t letter_style  \
# 7582          其他                      幼儿园《幼教三六五》杂志  2018-05-04           咨询
# 1397        卫生计生                                臭气  2011-08-25           建议
# 2380        交通运输       建议对856公交线路稍作微调，最大限度满足群众出行需求  2012-07-11           建议
# 3524        教育文体                      进城务工人员计生状况证明  2014-06-05           咨询
# 3990        交通运输                     新阳到嵩屿828晚班车开通  2015-05-28           感谢
# 4191        教育文体  作为优秀的共产党党员家庭，我们需要知道我们的孩子读书问题那么复杂  2015-07-04           投诉
# 6839        城乡建设                             保障房问题  2017-08-27           咨询
# 5026        交通运输                            海沧大桥拥堵  2016-04-19           投诉
# 6609        城乡建设                       兴港路沿线居民买菜困难  2017-08-08           建议
# 7077        经济管理                 海沧区服务中心外资企业变更咨询电话  2018-01-02           咨询
# 7111        城乡建设                    反映天乙广场房屋地板爆裂问题  2017-12-25           求助
# ...
