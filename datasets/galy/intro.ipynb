# %% [markdown]
# # galy 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/galy/galy.csv)
# 1. **数据概览：** 0.05 万条福建公安公众服务留言回复数据
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 福建公安公众服务
# 4. **加工处理：**
#     1. 过滤了id、url、number、time字段
#     2. 对title、content做了脱敏处理

# %%
import pandas as pd

# %%
path = 'galy_文件夹_所在_路径'

# %% [markdown]
# # 1.galy.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'galy.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | release_t | 发布时间 |
# | title | 诉讼标题 |
# | transfer_u | 转办单位 |
# | content | 诉讼内容 |
# | expect_t | 预计回复时间 |
# | reply_c | 回复意见 |
# | satisfy_d | 满意度 |
# | evaluate_t | 评论时间 |
# | evaluate_c | 评论内容 |

# %%
pd_all.sample(n=20)
# Out:
#      click_r   release_t                                        title  \
# 294        2   2013/6/20                           户证大厅在线申报网页材料信息文件上传
# 265      431   2009/11/9                                       非法诈骗网站
# 220      389   2010/1/26                            纳税人的钱都养这样没有素质的人吗?
# 442      501  2011/11/30                                   高考生身份证求急办理
# 127       31   2011/3/25                                这就是延平区户政科的回复？
# 241      123  2009/12/24                                           骗子
# 419      332    2012/5/4                          希望领导能帮助我消除我老家的违法状态。
# 306        3    2014/3/6              感谢安溪县公安局经侦的同志们，辛苦破了诈骗案，还电话通知受害人
# 59         5  2015/12/29  中经商品交易中心080号会员东方巨力厦门资产管理公司，涉嫌利用现货原油平台，搞经济诈骗
# 365       92   2013/2/18                         建议在横跨二环路的斑马线的红绿灯分段设置
# 429      121    2012/4/6                                          感谢信
# 444      881   2011/12/2                                    关于超龄子女的申请
# ...

# %% [markdown]
# ## 诉讼类型说明

# %%
pd_all['form'].unique()
# Out:
# array(['求决', '建议', '揭控', '咨询', '申诉', '其他', '表扬', '感谢', '举报'], dtype=object)
