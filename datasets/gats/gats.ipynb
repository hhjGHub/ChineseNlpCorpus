# %% [markdown]
# # gats 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/gats/gats.csv)
# 1. **数据概览：** 2.5 万条政务办理记录
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 厦门市人民政府
# 4. **加工处理：**
#     1. 过滤了id、url、number、time字段
#     2. 对title、content做了脱敏处理

# %%
import pandas as pd

# %%
path = 'gats_文件夹_所在_路径'

# %% [markdown]
# # 1.gats.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'gats.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | form | 诉讼类型 |
# | title | 诉讼标题 |
# | content | 诉讼内容 |
# | process| 办理过程 |
# | output| 办理结果 |
# | place | 事件地点 |

# %%
pd_all.sample(n=20)
# Out:
#       form                                              title  \
# 21951   求决                                     关于西亭社区没有幼儿园的问题
# 17426   求决  请政府主管部门要求各物业服务企业将服务办公场所标示的“xxx管理处”统一标示为“xxx服务处...
# 9083    揭控                                 举报湖里区钟宅村2022号的违章建筑
# 15647   求决                       担心民生银行大厦建设会对湖滨南路46号的楼房安全造成影响
# 2340    建议                                    规划建设一个高级商务,住宅中心
# 23968   求决                                   有关324国道路灯只亮一半的问题
# 19651   求决                               禾祥西路繁荣广场正对面道路拐角处长期积水
# 23745   申诉                                           关闭五缘湾足球场
# 15955   申诉           强烈要求尽快优化752公交岛内线路以方便翔安市民前往万达商场和前埔BRT站点换乘
# 16      咨询                                咨询残疾人康复补助金多久发放一次的问题
# 8865    建议                                                 鼠患
# 9405    求决                                 有关海峡出租车公司招出租车司机的问题
# 17168   建议                                         夜景灯浪费电，请关闭
# 8747    求决                                              厦门限价房
# ...

# %% [markdown]
# ## 诉讼类型说明

# %%
pd_all['form'].unique()
# Out:
# array(['求决', '建议', '揭控', '咨询', '申诉', '其他', '表扬', '感谢', '举报'], dtype=object)
