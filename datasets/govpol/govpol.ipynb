# %% [markdown]
# # govpol 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/govpol/govpol.csv)
# 1. **数据概览：** 2.9 万条厦门公安在线咨询数据
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 厦门公安--在线咨询
# 4. **加工处理：**
#     1. 过滤了id、url字段
#     2. 对title、content做了脱敏处理

# %%
import pandas as pd

# %%
path = 'govpol_文件夹_所在_路径'

# %% [markdown]
# # 1.govpol.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'govpol.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | style | 咨询分类 |
# | submit_t | 提交时间 |
# | title | 诉讼标题 |
# | content | 诉讼内容 |
# | evaluate | 咨询人评价 |
# | reply_con | 回复内容 |
# | reply_p| 回复人 |
# | reply_t | 回复时间 |

# %%
pd_all.sample(n=20)
# Out:
#        style    submit_t                title  \
# 618    出入境管理   2011/5/17  为什么网上办理完后，查不到办理情...
# 16105   户籍管理   2014/8/21                 户口回签
# 8297    户籍管理   2012/11/1  专业技术人员重新录用配偶户口随迁...
# 5796    户籍管理   2012/5/18  朋友新房送的户口指标我是否可以用...
# 21866   户籍管理   2016/1/14                 投资入户
# 17061   户籍管理  2014/11/18           离职集体户迁移被拒绝
# 26663   户籍管理   2017/6/27             毕业生档案与落户
# 11918   户籍管理    2013/8/1              毕业生户籍挂靠
# 22117   户籍管理   2016/2/26        结婚后能把户口迁入厦门吗？
# 767     户籍管理   2011/5/10               有关落户问题
# 26400   户籍管理   2017/5/23              身份证挂失补办
# 18355  出入境管理   2015/3/22       非厦门户籍厦大学生去金门旅游
# 19716   户籍管理   2015/7/20          户口本丢失，身份证过期
# 10180  出入境管理   2013/3/27                 护照遗失
# 2581     NaN    2011/9/5                 刻合同章
# 5630    户籍管理   2012/5/13                关于暂住证
# 26134   户籍管理    2017/5/2                居住证办理
# 14350   户籍管理   2014/3/30          应届毕业生户口迁回原籍
# 18870   户籍管理    2015/5/6                暂住证延期
# ...
