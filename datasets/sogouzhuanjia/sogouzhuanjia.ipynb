# %% [markdown]
# # sogouzhuanjia 说明
# 0. **下载地址：** [百度网盘](https://pan.baidu.com/s/1rJMt5q_6nMPCfrZgI_eW3Q)
# 1. **数据概览：** 11.6 万条律师问答数据
# 2. **推荐实验：** FAQ 问答系统
# 3. **数据来源：** 搜狗问答
# 4. **加工处理：**
#     1. 过滤了id、url、qid字段
#     2. 对title、question做了脱敏处理

# %%
import pandas as pd

# %%
path = 'sogouzhuanjia_文件夹_所在_路径'

# %% [markdown]
# # 1.sogouzhuanjia.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'sogouzhuanjia.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | tag | 标签 |
# | title | 标题 |
# | question | 问题 |
# | posttime | 提问时间 |
# | reply | 每个回答的内容 |
# | reply_t | 每个回答的时间 |

# %%
pd_all.sample(n=20)
# Out:
#          tag                                              title  \
# 71973   债权债务  我在东莞虎门一家公司上班，我是提前一个月辞职，还没有到我指定日前现在公司提前把我辞退了，我能...
# 58417   公司犯罪                       扩大经营，公司办公地与实际经营地不同，这个时候该怎么办？
# 36466   刑事辩护                       助力车子被扣的时候是未成年没去处理现在成年了处理会拘留吗
# 70000   房产纠纷                              怎么查开房记录网上怎么查开房记录？我想维权
# 32752    NaN                 QQ被他人盗了里面虽然没钱但是盗用QQ人乱加人还泄漏他人隐私能否报警
# 17575    NaN  你好，我订婚一年了，现在对方要求结婚，但是我们这结婚必须有房有车，所以我就问他要车和房子然后...
# 420      NaN                             有合同的，你可以帮忙打官司吗，方便留你电话吗
# 83011   债务债权  朋友从我这里借了5万元钱说是搞工程，十天之内还给我，结果到现在二年了没有还我，他把他现有的资...
# 37553    NaN  我们分居一年，他问我要十万，如果我不给他是不会和我离婚，我一时接受不了我自己在外面打工，现在...
# 20166   婚姻家庭                       女朋友怀孕已满16岁双方自愿孩子要打掉我需要付什么责任吗
# 101202   NaN                             劳动仲裁查询麻烦吗，直接拿证据过去就可以了吗
# 7975    婚姻家庭          您好我和老婆是这个月4号登记的她回娘家了说不和我过了如果我提出离婚可以要回彩礼吗？
# 21884     继承  您好，家里老人给我留下一套房子，户主写着老人名字，老人留下遗嘱并公证过，现在我们搬家了，老人...
# 31839   债务债权  王某与赵某与2004年结婚。赵某远在日本的叔叔早就表示赵某结婚时将给1万美元作为贺礼，200...
# ...

# %% [markdown]
# ## 纠纷类型

# %%
pd_all['tag'].unique()
# Out:
# array(['合同纠纷', '人身损害', nan, '继承', '债务债权', '交通事故', '工伤赔偿', '拆迁安置', '婚姻家庭',
#        '刑事辩护', '房产纠纷', '抵押担保', '离婚', '劳动纠纷', '侵权', '水利电力', '公安国安', '土地纠纷',
#        '网络侵权', '求学教育', '医疗纠纷', '取保候审', '电信通讯', '资产拍卖', '消费权益', '工程建筑',
#        '暴力犯罪', '保险理赔', '票据', '招商引资', '银行', '公司上市', '广告宣传', '移民留学', '期货交易',
#        '工商税务', '刑事自诉', '加盟维权', '金融证券', '死刑辩护', '股权纠纷', '毒品犯罪', '行政复议',
#        '合伙联营', '环境污染', '经销代理', '海关商检', '调解谈判', '知识产权', '兼并收购', '公司法',
#        '旅游', '法律文书代写', '邮政储蓄', '倾销补贴', '法律顾问', '合资合作', '行政诉讼', '工商查询',
#        '海事海商', '合同审查', '涉外仲裁', '经济犯罪', '融资借款', '反不正当竞争', '招标投标', '破产清算',
#        '个人独资', '公司犯罪', '商标', '债权债务', '税务', '网络法律', '建设工程', '综合咨询', '新三板',
#        '改制重组', '私人律师', '污染损害', '著作权', '专利', '涉外法律', '公司解散', '股权激励',
#        '外商投资', '经济仲裁', '高新技术'], dtype=object)
