# %% [markdown]
# # gaxf 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/gaxf/gaxf.csv)
# 1. **数据概览：** 0.08 万条福建公安公众服务信访回复数据
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 福建公安公众服务
# 4. **加工处理：**
#     1. 过滤了id、url、number、time字段
#     2. 对title、content做了脱敏处理

# %%
import pandas as pd

# %%
path = 'gaxf_文件夹_所在_路径'

# %% [markdown]
# # 1.gaxf.csv

# %% [markdown]
# ## 加载数据

# %%
# pd_all = pd.read_csv(path + 'gaxf.csv')
pd_all = pd.read_csv(r'D:/source/corpus/ChineseNlpCorpus/datasets/gaxf/gaxf.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | release_t | 发布时间 |
# | title | 诉讼标题 |
# | transfer_u | 转办单位 |
# | content | 诉讼内容 |
# | expect_t | 预计回复时间 |
# | reply_c | 回复意见 |
# | satisfy_d | 满意度 |
# | evaluate_t | 评论时间 |
# | evaluate_c | 评论内容 |

# %%
pd_all.sample(n=20)
# Out:
#      click_r   release_t                           title  \
# 327       94  2013/11/11                    请求把儿子的户口迁回原籍
# 34      3553    2017/4/1                      恳请领导伸出援助之手
# 541        5    2014/9/9                 关于已满16周岁更改姓氏的问题
# 493       60   2015/1/16                          车辆不给上牌
# 801     4766   2018/1/10            关于信件编号WSXF299872处理不服
# 73       515   2017/1/16                            电信诈骗
# 489       20    2015/1/7                        57岁老人没户口
# 184      388  2011/11/28                      华侨回国恢复户口问题
# 766       28   2015/5/26  《关于进一步加强交通技术监控违法行为处理工作的通知》还执行吗
# 415     4037    2013/5/9                        年龄错误要求更改
# 656       50    2016/4/1                 惠安县紫山派出所陈俊龙徇私枉法
# 522       13  2014/11/13             原始档安与现持有户口本姓名不一致怎么办
# 614        8    2014/3/4                         孩子上户后真难
# 684       24  2015/12/30               关于金座美容店涉嫌合同诈骗紧急信访
# 374       48   2013/7/18                             感谢！
# ...
