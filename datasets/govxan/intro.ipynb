# %% [markdown]
# # govxan 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/govxan/govxan.csv)
# 1. **数据概览：** 0.45 万条厦门市翔安区人民政府咨询投诉数据
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 厦门市翔安区人民政府--咨询投诉
# 4. **加工处理：**
#     1. 过滤了id、url字段
#     2. 对title、content做了脱敏处理

# %%
import pandas as pd

# %%
path = 'govxan_文件夹_所在_路径'

# %% [markdown]
# # 1.govxan.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'govxan.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | letter_type | 内容类型 |
# | title | 标题 |
# | post_t | 发表日期 |
# | letter_style| 信件类型 |
# | content_ask| 咨询内容 |
# | reply_dep | 答复部门 |
# | reply_t | 发布时间 |
# | reply_c | 答复内容 |

# %%
pd_all.sample(n=20)
# Out:
#      letter_type                       title      post_t letter_style  \
# 4025        城乡建设                  这不是另一种腐败？？  2015-05-18           投诉
# 806         交通运输                      850公交车  2010-10-04           建议
# 5512        城乡建设  海兴路菜市场严重影响海福广场小区业主车辆进出，求解决  2016-11-09           投诉
# 2399        交通运输             关于海沧幼儿园公交交通问题建议  2012-07-10           建议
# 3728          其他            在东孚镇开办生态果园需要什么手续  2014-08-22           建议
# 1102     科技与信息产业                       海沧湾公园  2011-05-03           建议
# 6385        城乡建设             拆迁在拆掉房子影响严重，望解决  2017-06-28           求助
# 5186          其他   15#######63未来橙堡蓝水郡门口私宰肉问题  2016-06-08           投诉
# 2971        卫生计生                      违规排放油烟  2013-05-21           投诉
# 245      劳动和社会保障                   海沧区编外教师问题  2010-03-11           投诉
# 3617        城乡建设                 有关城区道路提升的建议  2014-04-02           建议
# 5402        交通运输           芦坑村民出行不便，学生上下学不安全  2016-12-10           咨询
# ...
