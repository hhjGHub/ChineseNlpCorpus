# %% [markdown]
# # govsug 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/govsug/govsug.csv)
# 1. **数据概览：** 0.18 万条市民对厦门市集美区政府的建议数据
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 厦门市集美区人民政府
# 4. **加工处理：**
#     1. 过滤了id、url字段
#     2. 对title、content做了脱敏处理

# %%
import pandas as pd

# %%
path = 'govsug_文件夹_所在_路径'

# %% [markdown]
# # 1.govsug.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'govsug.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | style | 类型 |
# | section | 部门 |
# | deliver_t | 发表时间 |
# | title | 主题 |
# | content | 内容 |
# | reply_c| 答复意见 |
# | reply_t | 答复时间 |

# %%
pd_all.sample(n=20)
# Out:
#      style         section         deliver_t  \
# 418     建议            公安分局    2013/2/1 13:41
# 132     建议             NaN  2011/12/30 11:25
# 636     建议        建设局,集美城发    2014/8/10 8:50
# 608     建议         人社局,地税局   2014/8/18 22:04
# 1609    建议            杏滨中队   2016/12/1 22:25
# 1094    建议            公安分局    2015/2/7 13:30
# 1709    建议  集美街道,集美城发,集美街道   2016/9/26 14:08
# 1761    建议             交通局   2016/8/17 11:28
# 1066    建议             建设局   2015/3/23 21:46
# 707     建议             卫生局   2014/5/28 10:01
# 1303    建议             交通局     2016/4/7 9:37
# 134     建议             NaN   2012/1/15 10:49
# 1076    建议             建设局   2015/3/11 21:06
# 812     建议             建设局  2013/12/26 11:39
# 423     建议             建设局   2013/2/19 22:59
# 1156    建议           机关事务局  2014/11/18 13:21
# 170     建议             灌口镇    2017/9/29 1:40
# 124     建议             NaN  2011/12/15 16:20
# 1218    建议    市场监督管理局,集美中队    2016/3/7 11:53
# 1381    建议             商务局   2015/12/5 17:06
#
# ...
