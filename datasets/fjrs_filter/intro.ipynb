# %% [markdown]
# # fjrs_filter 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/fjrs_filter/fjrs_filter.csv)
# 1. **数据概览：** 0.45 万条福建省人力资源和社会保障厅厅长信箱数据
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 福建省人力资源和社会保障厅
# 4. **加工处理：**
#     1. 过滤了id、url字段
#     2. 对title、content做了脱敏处理

# %%
import pandas as pd

# %%
path = 'fjrs_filter_文件夹_所在_路径'

# %% [markdown]
# # 1.fjrs_filter.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'fjrs_filter.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | reporgs | 责任单位 |
# | title | 标题 |
# | content | 内容 |
# | posttime | 咨询时间 |
# | replytime | 回复时间 |
# | reply | 回复内容 |

# %%
pd_all.sample(n=20)
# Out:
#           reporgs                                title  \
# 2194    事业单位人事管理处                                 职称证书
# 602          考试中心                    福建省2017年注册安全工程师考试
# 2353        毕业生中心                                报到证咨询
# 2359        城乡居民保              为何我没有农村医保的卡？而是一本类似存折的册子
# 3472          NaN       请问；交不起七八万元巨款还能有什么根据自己的需要与实际可言？
# 2886          NaN                              社会保障卡注销
# 413     事业单位人事管理处                           怎么查询中级职称证书
# 1173        工资福利处                          有关工龄认定的几个问题
# 1139          办公室                                 户口问题
# 1812        毕业生中心                                报到证补办
# 161   劳动关系处;劳动关系处                             关于培训费的问题
# 2431    事业单位人事管理处                        专业技术人员任职资格评审表
# 3446          NaN                             城镇职工养老保险
# 2191        社会保险局                          社保金异地迁移政策咨询
# 3286          NaN                   咨询外地社保转移有没有成功，去哪查？
# 3275          NaN                        如何交企业职工基本养老保险
# ...
