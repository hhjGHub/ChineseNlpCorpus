# %% [markdown]
# # fjbspersonal 说明
# 0. **下载地址：** [github](https://github.com/SophonPlus/ChineseNlpCorpus/raw/master/datasets/fjbspersonal/fjbspersonal.csv)
# 1. **数据概览：** 1 万条福建省网上办事大厅市民办事数据
# 2. **推荐实验：** 舆情分析
# 3. **数据来源：** 福建省网上办事大厅
# 4. **加工处理：**
#     1. 过滤了id、url、infoprojid字段

# %%
import pandas as pd

# %%
path = 'fjbspersonal_文件夹_所在_路径'

# %% [markdown]
# # 1.fjbspersonal.csv

# %% [markdown]
# ## 加载数据

# %%
pd_all = pd.read_csv(path + 'fjbspersonal.csv')

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | area | 地区 |
# | topic | 主题 |
# | servicename | 事项名称 |
# | foruser | 申报对象 |
# | deptname | 办理机构 |
# | promiseday | 承诺时限 |
# | 网上申请最多窗口次数 | wscs |
# | 窗口申请最多去窗口次数 | ckcs |
# | 星级 | starprorepty |

# %%
pd_all.sample(n=20)
# Out:
#      area topic                      servicename  \
# 3749  海沧区  住房保障                   既有住宅增设电梯工程施工许可
# 477   厦门市  抵押质押                     机动车质押、解除质押备案
# 4941  思明区    其他                  申请参保人员自付医疗费困难补助
# 5996  思明区    其他                计划生育特殊家庭紧急救助审核、发放
# 561   厦门市  证件办理                 医师执业注册（港澳医师短期行医）
# 7907  海沧区    其他                       部分计生家庭奖励扶助
# 3178  思明区  离职退休                             居家护理
# 4057  海沧区  优待抚恤                       伤残军人评定认定初审
# 727   厦门市    其他       渔业船网工具指标的审批（省级委托事项）（可下乡办理）
# 6362  思明区    其他             独生子女死亡家庭首次再生育补助审核、发放
# 6572  湖里区  就业创业                区自主创业一次性奖励金申领（审核）
# 2310  思明区  社会保障                       参保人员医疗费用报销
# 5131  海沧区  证件办理                       流动人口婚育证明查验
# 4121  海沧区  优待抚恤  优抚对象和革命“五老”人员医疗门诊费、体检费等医疗补助金的审核
# 889   思明区  教育科研                    归侨学生、归侨子女身份认定
# 9924  翔安区  证件办理                    中华人民共和国残疾人证注销
# 9152  同安区  医疗卫生                 计划生育项目生育保险待遇审核给付
# 4077  海沧区  优待抚恤        重点优抚对象和“海工一团”退役人员生活困难临时救助
# ...
